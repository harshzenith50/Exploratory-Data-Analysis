# %%
#HARSH SINGH
# %matplotlib inline

# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import sklearn as skl

# %%
plt.style.use('dark_background')

# %%
#1
df=pd.read_csv("C:/Users/harsh/Desktop/Car_sales (1).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        157 non-null    object
#  1   Model               157 non-null    object
#  2   Sales in thousands  157 non-null    float64
#  3   x_4_year            121 non-null    float64
#  4   Vehicle type        157 non-null    object
#  5   Price in thousands  155 non-null    float64
#  6   Engine size         156 non-null    float64
#  7   Horsepower          156 non-null    float64
#  8   Wheelbase           156 non-null    float64
#  9   Width               156 non-null    float64
#  10  Length              156 non-null    float64
#  11  Curb weight         155 non-null    float64
#  12  Fuel capacity       156 non-null    float64
#  13  Fuel efficiency     154 non-null    float64
#  14  Latest Launch       157 non-null    object
# ...

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545       NaN
# 153  Volvo          S70                            15.245       NaN
# 154  Volvo          V70                            17.531       NaN
# 155  Volvo          C70                             3.493       NaN
# 156  Volvo          S80                            18.969       NaN
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.rename(columns={"Sales in thousands":"sales_in_thousands","Price in thousands":"price_in_thousands","Vehicle type":"vehicle_type","Engine size":"engine_size","Curb weight":"curb_weight","Fuel capacity":"fuel_capacity","Fuel efficiency":"fuel_efficiency","Latest Launch":"latest_launch"},inplace=True)

# %%
df
# Out:
#       Manufacturer              Model  sales_in_thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545       NaN
# 153  Volvo          S70                            15.245       NaN
# 154  Volvo          V70                            17.531       NaN
# 155  Volvo          C70                             3.493       NaN
# 156  Volvo          S80                            18.969       NaN
#
#     vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
plt.figure()
sb.boxplot(x=df.x_4_year)
#here we can see x_4_year has many outliers so we will choose median to fill null values
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#3
df['x_4_year'].fillna((df['x_4_year'].median()),inplace=True)

# %%
plt.figure()
sb.boxplot(df.price_in_thousands)
#here we can see price_in_thousands has many outliers so we will choose median to fill null values
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#3
df['price_in_thousands'].fillna((df['price_in_thousands'].median()),inplace=True)

# %%
plt.figure()
sb.boxplot(df.fuel_efficiency)
#here not much outliers are there so we use mean to replace null values
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#3
df['fuel_efficiency'].fillna((df['fuel_efficiency'].mean()),inplace=True)

# %%
plt.figure()
sb.boxplot(df.engine_size)
#here not much outliers are there so we use mode to replace null values
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#3
df['engine_size'].fillna((df['engine_size'].mean()),inplace=True)

# %%
#3
df['Horsepower'].fillna((df['Horsepower'].mean()),inplace=True)

# %%
#3
df['Wheelbase'].fillna((df['Wheelbase'].mean()),inplace=True)

# %%
#3
df['Width'].fillna((df['Width'].mean()),inplace=True)

# %%
#3
df['Length'].fillna((df['Length'].mean()),inplace=True)

# %%
#3
df['curb_weight'].fillna((df['curb_weight'].mean()),inplace=True)

# %%
#3
df['fuel_efficiency'].fillna((df['fuel_efficiency'].mean()),inplace=True)

# %%
#3
df['fuel_capacity'].fillna((df['fuel_capacity'].mean()),inplace=True)

# %%
plt.figure()
sb.boxplot(df.XX)
#here we can see XX has many outliers so we will choose median to fill null values
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#3
df['XX'].fillna((df['XX'].median()),inplace=True)

# %%
#4
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        157 non-null    object
#  1   Model               157 non-null    object
#  2   sales_in_thousands  157 non-null    float64
#  3   x_4_year            157 non-null    float64
#  4   vehicle_type        157 non-null    object
#  5   price_in_thousands  157 non-null    float64
#  6   engine_size         157 non-null    float64
#  7   Horsepower          157 non-null    float64
#  8   Wheelbase           157 non-null    float64
#  9   Width               157 non-null    float64
#  10  Length              157 non-null    float64
#  11  curb_weight         157 non-null    float64
#  12  fuel_capacity       157 non-null    float64
#  13  fuel_efficiency     157 non-null    float64
#  14  latest_launch       157 non-null    object
# ...

# %%
#4
df.shape #(no of rows, no of columns)
# Out:
# (157, 17)

# %%
#6
del df['Unnamed: 15']
del df['XX']

# %%
df
# Out:
#       Manufacturer              Model  sales_in_thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545    14.180
# 153  Volvo          S70                            15.245    14.180
# 154  Volvo          V70                            17.531    14.180
# 155  Volvo          C70                             3.493    14.180
# 156  Volvo          S80                            18.969    14.180
#
#     vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 0      Passenger              21.500          1.8       140.0      101.2
# ...

# %%
#7.1
print(df.Manufacturer[df.sales_in_thousands.idxmin()],df.Model[df.sales_in_thousands.idxmin()])
# Out:
# Mitsubishi    3000GT

# %%
#7.2
print(df.Manufacturer[df.sales_in_thousands.idxmax()],df.Model[df.sales_in_thousands.idxmax()])
# Out:
# Ford          F-Series

# %%
#7.3
df1 = df[df['vehicle_type']=='Passenger'] 
print(df1.Manufacturer[df1.sales_in_thousands.idxmin()],df1.Model[df1.sales_in_thousands.idxmin()])
# Out:
# Mitsubishi    3000GT

# %%
#7.4
df1=df[df['engine_size'] > 6] 
print(df1.Manufacturer[df1.sales_in_thousands.idxmax()],df1.Model[df1.sales_in_thousands.idxmax()])
# Out:
# Dodge         Viper

# %%
#7.5
df1=df[df['vehicle_type']=='Car']
print(df1.Manufacturer[df1.fuel_efficiency.idxmax()])
# Out:
# Toyota

# %%
#7.6
df1=df[df['vehicle_type']=='Passenger']
print(df1.Manufacturer[df1.fuel_efficiency.idxmin()])
# Out:
# Dodge

# %%
#7.7
print("Minimum Price: ",df.Manufacturer[df.price_in_thousands.idxmin()],"\nMaximum Sales: ",df.Manufacturer[df.sales_in_thousands.idxmax()])
# Out:
# Minimum Price:  Chevrolet
# Maximum Sales:  Ford

# %%
#7.7
df1=df.nsmallest(10, 'price_in_thousands')
df1
df2=df1.nlargest(1, 'sales_in_thousands')
df2
# Out:
#      Manufacturer              Model  sales_in_thousands  x_4_year  \
# 55  Ford           Ranger                         220.65      7.85
#
#    vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 55          Car               12.05          2.5       119.0      117.5
#
#     Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 55   69.4   200.7        3.086           20.0             23.0     14-Jan-14

# %%
#7.8
print("Maximum Price: ",df.Manufacturer[df.price_in_thousands.idxmax()],"\nMinimum Sales: ",df.Manufacturer[df.sales_in_thousands.idxmin()])
# Out:
# Maximum Price:  Mercedes-Benz
# Minimum Sales:  Mitsubishi

# %%
#7.8
df1=df.nlargest(10, 'price_in_thousands')
df1
df2=df1.nsmallest(1, 'sales_in_thousands')
df2
# Out:
#      Manufacturer              Model  sales_in_thousands  x_4_year  \
# 39  Dodge          Viper                           0.916     58.47
#
#    vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 39    Passenger              69.725          8.0       450.0       96.2
#
#     Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 39   75.7   176.7        3.375           19.0             16.0      8-Jul-15

# %%
#7.9
print(df.Model[df.Horsepower.idxmax()])
# Out:
# Viper

# %%
#7.10
print(df.Manufacturer[df.sales_in_thousands.idxmin() and df.fuel_efficiency.idxmax()],df.Model[df.sales_in_thousands.idxmin() and df.fuel_efficiency.idxmax()])
# Out:
# Chevrolet     Metro

# %%
#7.10
df1=df.nlargest(10, 'fuel_efficiency')
df1
df2=df1.nsmallest(1, 'sales_in_thousands')
df2
# Out:
#       Manufacturer              Model  sales_in_thousands  x_4_year  \
# 131  Saturn         SW                              5.223     10.79
#
#     vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 131    Passenger               14.29          1.9       124.0      102.4
#
#      Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 131   66.4   176.9        2.452           12.1             31.0     15-Jan-15

# %%
#7.11
print(df.Manufacturer[df.fuel_efficiency.idxmin() and df.sales_in_thousands.idxmax()],df.Model[ df.fuel_efficiency.idxmin() and df.sales_in_thousands.idxmax()  ])
# Out:
# Ford          F-Series

# %%
#7.11
df1=df.nsmallest(10, 'fuel_efficiency')
df1
df2=df1.nlargest(1, 'sales_in_thousands')
df2
# Out:
#      Manufacturer              Model  sales_in_thousands  x_4_year  \
# 40  Dodge          Ram Pickup                    227.061     15.06
#
#    vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 40          Car               19.46          5.2       230.0      138.7
#
#     Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 40   79.3   224.2         4.47           26.0             17.0      3-Jun-14

# %%
#7.12
df1=df[df['vehicle_type']=='Car']
print(df1.Manufacturer[df1.Wheelbase.idxmax()],df.Model[df1.Wheelbase.idxmax()])
# Out:
# Dodge         Ram Pickup

# %%
#7.13
df1=df[df['vehicle_type']=='Passenger']
print(df1.Manufacturer[df1.Wheelbase.idxmin()],df.Model[df1.Wheelbase.idxmin()])
# Out:
# Porsche       Carrera Coupe

# %%
#7.14
df1=df.nlargest(10, 'curb_weight')
df1
df2=df1.nlargest(1, 'fuel_efficiency')
df2
# Out:
#       Manufacturer              Model  sales_in_thousands  x_4_year  \
# 100  Mercedes-Benz  M-Class                        28.976     14.18
#
#     vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 100          Car                35.3          3.2       215.0      111.0
#
#      Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 100   72.2   180.6        4.387           19.0             20.0      2-Oct-15

# %%
#7.15
df1=df.nsmallest(10, 'curb_weight')
df1
df2=df1.nlargest(1, 'fuel_efficiency')
df2
# Out:
#      Manufacturer              Model  sales_in_thousands  x_4_year  \
# 26  Chevrolet      Metro                          21.855      5.16
#
#    vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 26   62.6   149.4        1.895           10.3             45.0     13-Apr-14

# %%
#7.16
df1=df.nsmallest(10, 'curb_weight')
df1
df2=df1.nsmallest(1, 'fuel_efficiency')
df2
# Out:
#      Manufacturer              Model  sales_in_thousands  x_4_year  \
# 79  Mitsubishi     Mirage                         26.232     8.325
#
#    vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 79    Passenger              13.987          1.8       113.0       98.4
#
#     Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 79   66.5   173.6         2.25           13.2             30.0     23-Apr-14

# %%
#7.18
df1=df.nlargest(10, 'sales_in_thousands')
df1
df2=df1.nlargest(1, 'x_4_year')
df2
# Out:
#      Manufacturer              Model  sales_in_thousands  x_4_year  \
# 52  Ford           Explorer                      276.747     16.64
#
#    vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 52          Car               31.93          4.0       210.0      111.6
#
#     Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 52   70.2   190.7        3.876           21.0             19.0     25-Apr-14

# %%
#7.19
df1=df.nlargest(20, 'sales_in_thousands')
df1
df2=df1.nlargest(10, 'fuel_efficiency')
df2
df3=df2.nlargest(5, 'x_4_year')
df3
df4=df3.nsmallest(1,'price_in_thousands')
df4
# Out:
#      Manufacturer              Model  sales_in_thousands  x_4_year  \
# 50  Ford           Focus                          175.67     14.18
#
#    vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 50    Passenger              12.315          2.0       107.0      103.0
#
#     Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 50   66.9   174.8        2.564           13.2             30.0     22-Jul-14

# %%
#7.20
df1=df.nsmallest(10, 'x_4_year')
df1
df2=df1.nlargest(1, 'sales_in_thousands')
df2
# Out:
#      Manufacturer              Model  sales_in_thousands  x_4_year  \
# 55  Ford           Ranger                         220.65      7.85
#
#    vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 55          Car               12.05          2.5       119.0      117.5
#
#     Width  Length  curb_weight  fuel_capacity  fuel_efficiency latest_launch
# 55   69.4   200.7        3.086           20.0             23.0     14-Jan-14

# %%
#7.21
df['sales_in_thousands'] = np.where((df.sales_in_thousands > df['sales_in_thousands'].mean()),df['sales_in_thousands'].mean(),df.sales_in_thousands)
df
# Out:
#       Manufacturer              Model  sales_in_thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545    14.180
# 153  Volvo          S70                            15.245    14.180
# 154  Volvo          V70                            17.531    14.180
# 155  Volvo          C70                             3.493    14.180
# 156  Volvo          S80                            18.969    14.180
#
#     vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 0      Passenger              21.500          1.8       140.0      101.2
# ...

# %%
#7.22
df['price_in_thousands'] = np.where((df.price_in_thousands > df['price_in_thousands'].mean()),df['price_in_thousands'].mean(),df.price_in_thousands)
df
# Out:
#       Manufacturer              Model  sales_in_thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545    14.180
# 153  Volvo          S70                            15.245    14.180
# 154  Volvo          V70                            17.531    14.180
# 155  Volvo          C70                             3.493    14.180
# 156  Volvo          S80                            18.969    14.180
#
#     vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 0      Passenger           21.500000          1.8       140.0      101.2
# ...

# %%
#7.23
df['Horsepower'] = np.where((df.Horsepower > df['Horsepower'].mean()),df['Horsepower'].mean(),df.Horsepower)
df
# Out:
#       Manufacturer              Model  sales_in_thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545    14.180
# 153  Volvo          S70                            15.245    14.180
# 154  Volvo          V70                            17.531    14.180
# 155  Volvo          C70                             3.493    14.180
# 156  Volvo          S80                            18.969    14.180
#
#     vehicle_type  price_in_thousands  engine_size  Horsepower  Wheelbase  \
# 0      Passenger           21.500000          1.8  140.000000      101.2
# ...

# %%
#7.17
df.rename(columns={"x_4_year":"4_Year_Resale_Value"})
# Out:
#       Manufacturer              Model  sales_in_thousands  \
# 0    Acura          Integra                        16.919
# 1    Acura          TL                             39.384
# 2    Acura          CL                             14.114
# 3    Acura          RL                              8.588
# 4    Audi           A4                             20.397
# ..             ...                ...                 ...
# 152  Volvo          V40                             3.545
# 153  Volvo          S70                            15.245
# 154  Volvo          V70                            17.531
# 155  Volvo          C70                             3.493
# 156  Volvo          S80                            18.969
#
#      4_Year_Resale_Value vehicle_type  price_in_thousands  engine_size  \
# 0                 16.360    Passenger           21.500000          1.8
# 1                 19.875    Passenger           27.332261          3.2
# ...

# %%
#5 placement data
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        157 non-null    object
#  1   Model               157 non-null    object
#  2   sales_in_thousands  157 non-null    float64
#  3   x_4_year            157 non-null    float64
#  4   vehicle_type        157 non-null    object
#  5   price_in_thousands  157 non-null    float64
#  6   engine_size         157 non-null    float64
#  7   Horsepower          157 non-null    float64
#  8   Wheelbase           157 non-null    float64
#  9   Width               157 non-null    float64
#  10  Length              157 non-null    float64
#  11  curb_weight         157 non-null    float64
#  12  fuel_capacity       157 non-null    float64
#  13  fuel_efficiency     157 non-null    float64
#  14  latest_launch       157 non-null    object
# ...
